# %% [markdown]
# <a href="https://colab.research.google.com/github/innysik222/Python-Libs/blob/main/Lib_sklearn_addition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Дополнительные задания:
# 1). Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
data=load_wine()

# %% [markdown]
# 2). Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# 3). Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.

# %%
Data=data['data']
print(Data.shape)
print(data['feature_names'])
# Out:
# (178, 13)
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %%
print(data['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# 4). Сколько классов содержит целевая переменная датасета? Выве дите названия классов.

# %%
target=data['target']
print(set(target))
print(len(set(target)))
# Out:
# {0, 1, 2}
# 3

# %% [markdown]
# 5). На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X.

# %%
X=pd.DataFrame(Data, columns=data['feature_names'])
X.head()
# Out:
#    alcohol  malic_acid   ash  ...   hue  od280/od315_of_diluted_wines  proline
# 0    14.23        1.71  2.43  ...  1.04                          3.92   1065.0
# 1    13.20        1.78  2.14  ...  1.05                          3.40   1050.0
# 2    13.16        2.36  2.67  ...  1.03                          3.17   1185.0
# 3    14.37        1.95  2.50  ...  0.86                          3.45   1480.0
# 4    13.24        2.59  2.87  ...  1.04                          2.93    735.0
#
# [5 rows x 13 columns]

# %% [markdown]
# 6). Выясните размер датафрейма X и установите, имеются ли в нем пропущенные значения.

# %%
X.shape
# Out:
# (178, 13)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# 7). Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.

# %%
X['target']=target.astype(np.int64)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# 8). Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr..

# %%
X_corr=X.corr()
X_corr
# Out:
#                                alcohol  malic_acid  ...   proline    target
# alcohol                       1.000000    0.094397  ...  0.643720 -0.328222
# malic_acid                    0.094397    1.000000  ... -0.192011  0.437776
# ash                           0.211545    0.164045  ...  0.223626 -0.049643
# alcalinity_of_ash            -0.310235    0.288500  ... -0.440597  0.517859
# magnesium                     0.270798   -0.054575  ...  0.393351 -0.209179
# total_phenols                 0.289101   -0.335167  ...  0.498115 -0.719163
# flavanoids                    0.236815   -0.411007  ...  0.494193 -0.847498
# nonflavanoid_phenols         -0.155929    0.292977  ... -0.311385  0.489109
# proanthocyanins               0.136698   -0.220746  ...  0.330417 -0.499130
# color_intensity               0.546364    0.248985  ...  0.316100  0.265668
# hue                          -0.071747   -0.561296  ...  0.236183 -0.617369
# ...

# %%
import seaborn as sns
sns.heatmap(X_corr, annot = True)

# %% [markdown]
# 9). Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).

# %%
high_corr=X_corr['target']
high_corr=high_corr[np.abs(high_corr)>0.5].drop("target",0)
high_corr=list(high_corr.index)
high_corr
# Out:
# ['alcalinity_of_ash',
#  'total_phenols',
#  'flavanoids',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# 10). Удалите из датафрейма X поле с целевой переменной. Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака. Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.

# %%
X=X.drop(target)
for i in high_corr:
  X[i+'_2']=X[i]**2
X
# Out:
#      alcohol  malic_acid  ...  od280/od315_of_diluted_wines_2  proline_2
# 3      14.37        1.95  ...                         11.9025  2190400.0
# 4      13.24        2.59  ...                          8.5849   540225.0
# 5      14.20        1.76  ...                          8.1225  2102500.0
# 6      14.39        1.87  ...                         12.8164  1664100.0
# 7      14.06        2.15  ...                         12.8164  1677025.0
# ..       ...         ...  ...                             ...        ...
# 173    13.71        5.65  ...                          3.0276   547600.0
# 174    13.40        3.91  ...                          2.4336   562500.0
# 175    13.27        4.28  ...                          2.4336   697225.0
# 176    13.17        2.59  ...                          2.6244   705600.0
# 177    14.13        4.10  ...                          2.5600   313600.0
#
# [175 rows x 20 columns]

# %%
X.describe()
# Out:
#           alcohol  malic_acid  ...  od280/od315_of_diluted_wines_2     proline_2
# count  175.000000  175.000000  ...                      175.000000  1.750000e+02
# mean    12.991543    2.342971  ...                        7.236390  6.469073e+05
# std      0.813193    1.124923  ...                        3.541693  5.554692e+05
# min     11.030000    0.740000  ...                        1.612900  7.728400e+04
# 25%     12.350000    1.595000  ...                        3.705650  2.500000e+05
# 50%     13.050000    1.870000  ...                        7.728400  4.356000e+05
# 75%     13.675000    3.110000  ...                       10.017250  9.094345e+05
# max     14.830000    5.800000  ...                       16.000000  2.822400e+06
#
# [8 rows x 20 columns]
